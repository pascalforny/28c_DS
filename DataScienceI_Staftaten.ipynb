# %%
import pandas as pd

# %%
#hier wird eine CSV-Datei geladen
dataframe = pd.read_csv("19-01-02_registrierte_Straftaten_einzeln.csv")
print(dataframe)

# %%
#so können wir nur einen Teil der Daten auswerten
dataframe = dataframe.loc[dataframe['jahr'] == 2009]

# %%
#So können wir den mean (Durchschnitt für alle numerischen Spalten berechnen)
dataframe.mean(numeric_only = True)

# %%
#So können wir den Median berechnen
dataframe.median(numeric_only = True)

# %% [markdown]
# Aufgabe: finde heraus, wie viele "Taschendiebstahl (Art. 139)" es durchschnittlich in den Vergangenen Jahren gab

# %%
#lade nochmals CSV-Datei neu
dataframe = pd.read_csv("19-01-02_registrierte_Straftaten_einzeln.csv")
print(dataframe)

# %%
#ersetze diese "???" jeweils mit den richtigen Daten (anaolog zu oben)
dataframe = dataframe.loc[dataframe['???'] == ???]

# %% [markdown]
# Weitere Aufgaben:
# - Nachdem wir Mittelwert und Median (Lagemasse) berechnet haben können wir auch Varianz (Streumasse) berechnen (https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html#pandas.DataFrame.std)
# - Lade einen Datensatz deiner Wahl in dieses Notebook und berechne Kennzahlen. Was findest du heraus?
